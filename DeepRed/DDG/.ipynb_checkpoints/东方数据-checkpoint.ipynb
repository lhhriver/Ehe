# %%
import os
import requests
import json   
import time    
import numpy as np
import pandas as pd
from pprint import pprint
import datetime

# %%
yesterday = (datetime.datetime.now() - datetime.timedelta(days=1)).strftime('%Y%m%d')
yesterday
# Out:
# '20230202'

# %%
today = datetime.datetime.now().strftime('%Y%m%d')
today
# Out:
# '20230203'

# %%
# time_stamp = time.time()    #取出时间戳
# time_stamp = int(time_stamp*1000)   #将10位整数变为13位整数
# print(time_stamp)
# page = 10 #input("请输入你想要爬取的页数:")


# # url = 'http://41.push2.eastmoney.com/api/qt/clist/get'
# url = 'http://71.push2.eastmoney.com/api/qt/clist/get?'
headers = {
    'Referer':
    'http://quote.eastmoney.com/',
    'User-Agent':
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36'
}

# #这个参数列表
# datas = {
#     'cb': f'jQuery112403210602285843305_{time_stamp}',
#     'pn': f'{page}',
#     'pz': '20',
#     'po': '1',
#     'np': '1',
#     'ut': 'bd1d9ddb04089700cf9c27f6f7426281',
#     'fltt': '2',
#     'invt': '2',
#     'fid': 'f3',
#     'fs': 'm:1 s:2',
#     'fields':
#     'f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f12,f13,f14,f15,f16,f17,f18,f20,f21,f23,f24,f25,f22,f11,f62,f128,f136,f115,f152',
#     '_': f'{time_stamp}'
# }

# %% [markdown]
# # 爬取今天数据

# %%
url = """http://71.push2.eastmoney.com/api/qt/clist/get?cb=jQuery112403210602285843305_1675345303710&pn=%s&pz=20&po=1&np=1&ut=bd1d9ddb04089700cf9c27f6f7426281&fltt=2&invt=2&wbp2u=|0|0|0|web&fid=f3&fs=m:0+t:6,m:0+t:80,m:1+t:2,m:1+t:23,m:0+t:81+s:2048&fields=f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f12,f13,f14,f15,f16,f17,f18,f20,f21,f23,f24,f25,f22,f11,f62,f128,f136,f115,f152&_=1675345303757"""

# %%
def get_data_pn(url, pn):
    url = url % pn
    # jsondata = requests.get(url=url, headers=headers, params=datas).text  # 输出文本
    jsondata = requests.get(url=url, headers=headers).text  # 输出文本
    
    data_pn_li = []
    start_data = jsondata.index('{"rc":0,')  # 取出前面文本
    end_data = jsondata.index('}]}}') + len('}]}}')  # 取出后面文本
    for json_data in json.loads(jsondata[start_data:end_data])['data']['diff']:
        info_tmp = []
        info_tmp.append(json_data['f12'])  # 名称
        info_tmp.append(json_data['f14'])  # 代码
        info_tmp.append(json_data['f2'])  # 最新价
        info_tmp.append(json_data['f17'])  # 今开
        info_tmp.append(json_data['f18'])  # 昨收
        # info_tmp.append(json_data['f15'])  # 最高
        # info_tmp.append(json_data['f16'])  # 最低
        # info_tmp.append(json_data['f8'])  # 换手率
        # info_tmp.append(json_data['f23'])  # 市净率
        data_pn_li.append(info_tmp)
    return data_pn_li

# %%
# data_all_li

# %%
data_res_file = "data/all_data_%s.json" % today
if not os.path.exists(data_res_file):
    print(">>>初始化结果文件")
    pn_li = [pn for pn in range(1,265)]
    data_pn_res = []
    
    all_data_json={}
    all_data_json["pn"] = pn_li
    all_data_json['data'] = data_pn_res
    json.dump(all_data_json, open(data_res_file, "w", encoding="utf-8"))
else:
    print(">>>读取结果数据")
    all_data_json = json.load(open(data_res_file, "r", encoding="utf-8"))
    pn_li = all_data_json["pn"]
    data_pn_res = all_data_json['data']
# Out:
# >>>初始化结果文件

# %%
pn_per = []
for pn in pn_li:
    try:
        time.sleep(1)
        print(">>> 正在处理第%s页" % pn)
        data_pn_tmp = get_data_pn(url, pn)
        pn_per.append(pn)
        data_pn_res.extend(data_pn_tmp)
    except Exception as e:
        print(">>> 异常", pn, e)
        all_data_json["pn"] = list(set(pn_li) - set(pn_per))
        all_data_json["data"] = data_pn_res
        json.dump(all_data_json, open(data_res_file, "w", encoding="utf-8"))
        
print("任务完成".center(20, "*"))
all_data_json["pn"] = list(set(pn_li) - set(pn_per))
all_data_json["data"] = data_pn_res
json.dump(all_data_json, open(data_res_file, "w", encoding="utf-8"))
# Out:
# >>> 正在处理第1页
# >>> 正在处理第2页
# >>> 正在处理第3页
# >>> 正在处理第4页
# >>> 正在处理第5页
# >>> 正在处理第6页
# >>> 正在处理第7页
# >>> 正在处理第8页
# >>> 正在处理第9页
# >>> 正在处理第10页
# >>> 正在处理第11页
# >>> 正在处理第12页
# >>> 正在处理第13页
# >>> 正在处理第14页
# >>> 正在处理第15页
# >>> 正在处理第16页
# >>> 正在处理第17页
# >>> 正在处理第18页
# >>> 正在处理第19页
# >>> 正在处理第20页
# >>> 正在处理第21页
# >>> 正在处理第22页
# >>> 正在处理第23页
# >>> 正在处理第24页
# >>> 正在处理第25页
# >>> 正在处理第26页
# >>> 正在处理第27页
# >>> 正在处理第28页
# >>> 正在处理第29页
# >>> 正在处理第30页
# >>> 正在处理第31页
# >>> 正在处理第32页
# >>> 正在处理第33页
# >>> 正在处理第34页
# >>> 正在处理第35页
# >>> 正在处理第36页
# >>> 正在处理第37页
# >>> 正在处理第38页
# >>> 正在处理第39页
# >>> 正在处理第40页
# >>> 正在处理第41页
# >>> 正在处理第42页
# >>> 正在处理第43页
# >>> 正在处理第44页
# >>> 正在处理第45页
# >>> 正在处理第46页
# >>> 正在处理第47页
# >>> 正在处理第48页
# >>> 正在处理第49页
# >>> 正在处理第50页
# >>> 正在处理第51页
# >>> 正在处理第52页
# >>> 正在处理第53页
# >>> 正在处理第54页
# >>> 正在处理第55页
# >>> 正在处理第56页
# >>> 正在处理第57页
# >>> 正在处理第58页
# >>> 正在处理第59页
# >>> 正在处理第60页
# >>> 正在处理第61页
# >>> 正在处理第62页
# >>> 正在处理第63页
# >>> 正在处理第64页
# >>> 正在处理第65页
# >>> 正在处理第66页
# >>> 正在处理第67页
# >>> 正在处理第68页
# >>> 正在处理第69页
# >>> 正在处理第70页
# >>> 正在处理第71页
# >>> 正在处理第72页
# >>> 正在处理第73页
# >>> 正在处理第74页
# >>> 正在处理第75页
# >>> 正在处理第76页
# >>> 正在处理第77页
# >>> 正在处理第78页
# >>> 正在处理第79页
# >>> 正在处理第80页
# >>> 正在处理第81页
# >>> 正在处理第82页
# >>> 正在处理第83页
# >>> 正在处理第84页
# >>> 正在处理第85页
# >>> 正在处理第86页
# >>> 正在处理第87页
# >>> 正在处理第88页
# >>> 正在处理第89页
# >>> 正在处理第90页
# >>> 正在处理第91页
# >>> 正在处理第92页
# >>> 正在处理第93页
# >>> 正在处理第94页
# >>> 正在处理第95页
# >>> 正在处理第96页
# >>> 正在处理第97页
# >>> 正在处理第98页
# >>> 正在处理第99页
# >>> 正在处理第100页
# >>> 正在处理第101页
# >>> 正在处理第102页
# >>> 正在处理第103页
# >>> 正在处理第104页
# >>> 正在处理第105页
# >>> 正在处理第106页
# >>> 正在处理第107页
# >>> 正在处理第108页
# >>> 正在处理第109页
# >>> 正在处理第110页
# >>> 正在处理第111页
# >>> 正在处理第112页
# >>> 正在处理第113页
# >>> 正在处理第114页
# >>> 正在处理第115页
# >>> 正在处理第116页
# >>> 正在处理第117页
# >>> 正在处理第118页
# >>> 正在处理第119页
# >>> 正在处理第120页
# >>> 正在处理第121页
# >>> 正在处理第122页
# >>> 正在处理第123页
# >>> 正在处理第124页
# >>> 正在处理第125页
# >>> 正在处理第126页
# >>> 正在处理第127页
# >>> 正在处理第128页
# >>> 正在处理第129页
# >>> 正在处理第130页
# >>> 正在处理第131页
# >>> 正在处理第132页
# >>> 正在处理第133页
# >>> 正在处理第134页
# >>> 正在处理第135页
# >>> 正在处理第136页
# >>> 正在处理第137页
# >>> 正在处理第138页
# >>> 正在处理第139页
# >>> 正在处理第140页
# >>> 正在处理第141页
# >>> 正在处理第142页
# >>> 正在处理第143页
# >>> 正在处理第144页
# >>> 正在处理第145页
# >>> 正在处理第146页
# >>> 正在处理第147页
# >>> 正在处理第148页
# >>> 正在处理第149页
# >>> 正在处理第150页
# >>> 正在处理第151页
# >>> 正在处理第152页
# >>> 正在处理第153页
# >>> 正在处理第154页
# >>> 正在处理第155页
# >>> 正在处理第156页
# >>> 正在处理第157页
# >>> 正在处理第158页
# >>> 正在处理第159页
# >>> 正在处理第160页
# >>> 正在处理第161页
# >>> 正在处理第162页
# >>> 正在处理第163页
# >>> 正在处理第164页
# >>> 正在处理第165页
# >>> 正在处理第166页
# >>> 正在处理第167页
# >>> 正在处理第168页
# >>> 正在处理第169页
# >>> 正在处理第170页
# >>> 正在处理第171页
# >>> 正在处理第172页
# >>> 正在处理第173页
# >>> 正在处理第174页
# >>> 正在处理第175页
# >>> 正在处理第176页
# >>> 正在处理第177页
# >>> 正在处理第178页
# >>> 正在处理第179页
# >>> 正在处理第180页
# >>> 正在处理第181页
# >>> 正在处理第182页
# >>> 正在处理第183页
# >>> 正在处理第184页
# >>> 正在处理第185页
# >>> 正在处理第186页
# >>> 正在处理第187页
# >>> 正在处理第188页
# >>> 正在处理第189页
# >>> 正在处理第190页
# >>> 正在处理第191页
# >>> 正在处理第192页
# >>> 正在处理第193页
# >>> 正在处理第194页
# >>> 正在处理第195页
# >>> 正在处理第196页
# >>> 正在处理第197页
# >>> 正在处理第198页
# >>> 正在处理第199页
# >>> 正在处理第200页
# >>> 正在处理第201页
# >>> 正在处理第202页
# >>> 正在处理第203页
# >>> 正在处理第204页
# >>> 正在处理第205页
# >>> 正在处理第206页
# >>> 正在处理第207页
# >>> 正在处理第208页
# >>> 正在处理第209页
# >>> 正在处理第210页
# >>> 正在处理第211页
# >>> 正在处理第212页
# >>> 正在处理第213页
# >>> 正在处理第214页
# >>> 正在处理第215页
# >>> 正在处理第216页
# >>> 正在处理第217页
# >>> 正在处理第218页
# >>> 正在处理第219页
# >>> 正在处理第220页
# >>> 正在处理第221页
# >>> 正在处理第222页
# >>> 正在处理第223页
# >>> 正在处理第224页
# >>> 正在处理第225页
# >>> 正在处理第226页
# >>> 正在处理第227页
# >>> 正在处理第228页
# >>> 正在处理第229页
# >>> 正在处理第230页
# >>> 正在处理第231页
# >>> 正在处理第232页
# >>> 正在处理第233页
# >>> 正在处理第234页
# >>> 正在处理第235页
# >>> 正在处理第236页
# >>> 正在处理第237页
# >>> 正在处理第238页
# >>> 正在处理第239页
# >>> 正在处理第240页
# >>> 正在处理第241页
# >>> 正在处理第242页
# >>> 正在处理第243页
# >>> 正在处理第244页
# >>> 正在处理第245页
# >>> 正在处理第246页
# >>> 正在处理第247页
# >>> 正在处理第248页
# >>> 正在处理第249页
# >>> 正在处理第250页
# >>> 正在处理第251页
# >>> 正在处理第252页
# >>> 正在处理第253页
# >>> 正在处理第254页
# >>> 正在处理第255页
# >>> 正在处理第256页
# >>> 正在处理第257页
# >>> 正在处理第258页
# >>> 正在处理第259页
# >>> 正在处理第260页
# >>> 正在处理第261页
# >>> 正在处理第262页
# >>> 正在处理第263页
# >>> 正在处理第264页
# ********任务完成********

# %%
data_today = pd.DataFrame(all_data_json["data"], columns = ['代码', '名称', '最新价', '今开', '昨收'])
data_today["获取时间"] = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
data_today.to_csv("data/all_data_" + today + ".csv", encoding="utf-8", index=False)

# %%
data_today
# Out:
#           代码       名称    最新价     今开     昨收                 获取时间
# 0     688228      开普云  46.68   39.9   38.9  2023-02-03 11:06:40
# 1     300114     中航电测  15.24  15.24   12.7  2023-02-03 11:06:40
# 2     300071     福石控股   5.53   4.63   4.61  2023-02-03 11:06:40
# 3     300553     集智股份  70.27  61.28   60.6  2023-02-03 11:06:40
# 4     688327  云从科技-UW  27.62   24.5  23.88  2023-02-03 11:06:40
# ...      ...      ...    ...    ...    ...                  ...
# 5275  002762     金发拉比  12.49   13.3  13.78  2023-02-03 11:06:40
# 5276  603606     东方电缆  55.42     61  61.21  2023-02-03 11:06:40
# 5277  002708     光洋股份   7.96   8.27   8.81  2023-02-03 11:06:40
# 5278  002403      爱仕达  11.12  11.31  12.34  2023-02-03 11:06:40
# 5279  002808     恒久科技  15.68  16.53  17.42  2023-02-03 11:06:40
#
# [5280 rows x 6 columns]

# %% [markdown]
# # 读取昨天数据

# %%
data_yesterday = pd.read_csv("all_data_" + yesterday + ".csv", encoding = "utf-8", dtype={'代码': object})
data_yesterday.columns = ['代码', '名称', '最新价', '昨开', '前收', '获取时间']
# data_yesterday

# %%
data_today = pd.read_csv("data/all_data_" + today + ".csv", encoding = "utf-8", dtype={'代码': object})
# data_today

# %%
data_all_new = pd.merge(data_today, data_yesterday[['代码',  '昨开']], on = ['代码'], how = "inner")

# %%
data_all_new = data_all_new[data_all_new['最新价']!="-"]
data_all_new = data_all_new[data_all_new['今开']!="-"]
data_all_new = data_all_new[data_all_new['昨开']!="-"]
data_all_new = data_all_new[data_all_new['昨收']!="-"]
data_all_new = data_all_new[['代码', '名称', '最新价', '今开', '昨开', '昨收', '获取时间']]

for col in ['最新价', '今开', '昨开', '昨收']:
    data_all_new[col] = data_all_new[col].astype(np.float64)

# %%
data_all_new["A"] = (data_all_new["最新价"]- data_all_new["昨收"]) / (data_all_new["昨开"]  -data_all_new["昨收"])   
# data_all_new["A"] = data_all_new["A"].apply(lambda x: format(x, '.2%'))

# %%
data_all_new
# Out:
#           代码    名称    最新价     今开     昨开     昨收                 获取时间         A
# 4868  000001  平安银行  14.24  14.45  14.74  14.60  2023-02-03 11:06:40 -2.571429
# 2017  000005  ST星源   1.83   1.84   1.86   1.84  2023-02-03 11:06:40 -0.500000
# 2018  000005  ST星源   1.82   1.84   1.86   1.84  2023-02-03 11:06:40 -1.000000
# 3791  000006  深振业Ａ   5.44   5.51   5.51   5.53  2023-02-03 11:06:40  4.500000
# 3790  000006  深振业Ａ   5.45   5.51   5.51   5.53  2023-02-03 11:06:40  4.000000
# ...      ...   ...    ...    ...    ...    ...                  ...       ...
# 104   873152  天宏锂电  15.05  14.80  14.80  14.45  2023-02-03 11:06:40  1.714286
# 4858  873169  七丰精工   6.75   6.85   6.80   6.92  2023-02-03 11:06:40  1.416667
# 1505  873305  九菱科技  10.59  10.60  10.88  10.60  2023-02-03 11:06:40 -0.035714
# 1587  873339  恒太照明   5.40   5.43   5.60   5.41  2023-02-03 11:06:40 -0.052632
# 1069  873527   夜光明   8.61   8.68   8.86   8.60  2023-02-03 11:06:40  0.038462
#
# [5075 rows x 8 columns]

# %%
data_all_new[data_all_new['A'].between(0.5,1.5)]
# Out:
#           代码    名称    最新价     今开     昨开     昨收                 获取时间         A
# 902   000010  美丽生态   3.47   3.47   3.47   3.46  2023-02-03 11:06:40  1.000000
# 4562  000011  深物业A  11.23  11.55  11.30  11.46  2023-02-03 11:06:40  1.437500
# 4910  000014  沙河股份  10.67  10.90  10.67  10.95  2023-02-03 11:06:40  1.000000
# 653   000023  深天地Ａ  11.77  11.69  11.80  11.69  2023-02-03 11:06:40  0.727273
# 115   000026   飞亚达  12.99  12.58  13.22  12.49  2023-02-03 11:06:40  0.684932
# ...      ...   ...    ...    ...    ...    ...                  ...       ...
# 2118  870866  绿亨科技   6.60   6.64   6.61   6.64  2023-02-03 11:06:40  1.333333
# 236   871642  通易航天   8.22   8.00   8.17   8.03  2023-02-03 11:06:40  1.357143
# 153   871981  晶赛科技  14.61  14.02  14.51  14.14  2023-02-03 11:06:40  1.270270
# 2282  872190  雷神科技  19.88  20.16  19.82  20.02  2023-02-03 11:06:40  0.700000
# 4858  873169  七丰精工   6.75   6.85   6.80   6.92  2023-02-03 11:06:40  1.416667
#
# [644 rows x 8 columns]

# %%
# flag_ss = data_all_new['代码'].str.startswith("0") | data_all_new['代码'].str.startswith("6")

# %%
# data_all_new[flag_ss]

# %%
data_all_new = data_all_new.sort_values(['代码'])
data_all_new["代码"] = "\t" + data_all_new["代码"]
data_all_new.to_csv("data/data_all_result_"+ today + ".csv", index=False)
