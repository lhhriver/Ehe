# %%
import os

file_dir = "../../"
file_dir = os.path.abspath(file_dir)

all_md_li = []
paths_li = []
dir_set = set()  # 当前目录

for root, dirs, files in os.walk(file_dir):
    root = root[15:].replace("\\", "/")

    if ".git" not in root and "N02-ICB" not in root:
        for file in files:
            if file not in ["readme.md", "README.md", "Readme.md"]:
                if os.path.splitext(file)[1] == '.' + "md":
                    dir_tmp_li = root.split("/")

                    # 标题
                    for i in range(len(dir_tmp_li)):
                        if "&&".join(dir_tmp_li[:i+1]) not in dir_set:
                            dir_set.add("&&".join(dir_tmp_li[:i+1]))
                            all_md_li.append("#" * (i + 1) + " " + dir_tmp_li[i])
                            print("#" * (i + 1) + " " + dir_tmp_li[i])

                    # 文章
                    all_md_li.append("[🔖 %s](%s)" % (os.path.splitext(file)[0], os.path.join(root, file).replace("\\", "/").replace(" ", "%20")))
                    paths_li.append(os.path.join(root, file).replace("\\", "/").replace(" ", "%20"))
            
# 目录
with open(os.path.join(file_dir, "N06-Blog/N09-Docsify/ICEhe", "N00-all_in_one.md"), "w", encoding="utf-8") as f:
    for li in all_md_li:
        f.write(li+"\n\n")
        
# 路径
with open(os.path.join(file_dir, "N06-Blog/N09-Docsify/static/js", "paths.js"), "w", encoding="utf-8") as f:
    f.write("paths = [\n")
    for li in paths_li:
        f.write("\"%s\"" % li+",\n")
    f.write("]\n\n")
# Out:
# # N01-DigitalCircuit
# ## N01-数电基础【修仙版】
# ### N01-课后作业
# # N02-Verilog
# ## N01-Verilog教程【基础篇】
# ## N02-Verilog教程【高级篇】
# ## N03-Verilog教程【修仙版】
# ### 课后作业
# ## N09-Verilog项目【实战篇】
# ### N02-Verilog HDL程序设计教程
# ### N03-牛客网刷题
# ### N04-HDLBits刷题
# # N03-SystemVerilog
# ## N01-SystemVerilog验证【蓝三版】
# ### N01-SystemVerilog笔记
# ## N02-SystemVerilog验证【绿皮版】
# ## N03-SystemVerilog教程【修仙版】
# ## N04-SystemVerilog设计模式【知乎版】
# ## N09-SystemVerilog项目【实战篇】
# ### N01-Router_Lab
# ### N02-FIFO_Lab
# #### Codes
# ### N03-Memory_Lab
# # N04-UVM
# ## N01-UVM实战【白皮版】
# ## N02-UVM教程【修仙版】
# ### N01-课后作业
# ## N09-UVM项目【实战篇】
# ### N01-UART项目实训
# #### src
# #### 提交作业
# ### N02-SPI项目实训
# #### src
# ##### rtl
# ##### uvc
# #### 提交作业
# ### N03-ahb2apb项目实训
# #### src
# ##### uvc
# #### 作业
# ### N04-sub_system项目实训
# #### 作业
# ### src
# #### uvc
# ##### ahb_master_uvc
# ##### apb_uvc
# ##### spi_slave_uvc
# ##### uart_uvc
# # N05-EDA
# # N06-Blog
# ## N01-STB
# ## N03-TPB
# ### N02-Verilog
# ### N03-SystemVerilog
# ### N05-EDA
# ### N06-Base
# ## N04-MindMap
# ## N05-硅思相见
# ### N01-Verilog_SystemVerilog_SVR
# ### N02-UVM
# ### N03-Quartus
# ### N04-MS
# ### N05-Other
# ## N09-Docsify
# ### ICEhe
# # N07-BasePL
# ## N01-Shell编程
# ## N02-Python
# ### N01-基础知识
# ### N02-Python中文指南
# ### N03-Python魔法指南
# ### N04-常用模块
# ### N05-专题知识
# ### N06-Python实例
# ## N03-C
# ### N01-C和指针
# ### N02-clang-tutorial
# ### N03-CNote-main
# #### N01-基础
# #### N02-入门
# #### N03-进阶
# ### N06-Exercise
# ## N04-C++
# ### N01-C++基础知识
# ### N02-C++基础教程
# ### N03-C++ Primer Plus
# ### N04-极简C++
# # N08-Protocol
# ## AMBA总线协议
# ## N06-PBlog
# # N09-NoteBook
# ## Jupyter
# # N10-Other
# ## N01-从业指导
# ## N02-题库
# ### N01-面试题库
# ### N02-网络题库
# ## N06-演武场
# ## N11-TMP
# ### N01-硅芯思见
# # N12-CodeBase
# ## N01-Verilog
# ### Verilog HDL 程序设计教程
# ## N03-UVM
# ### N02-ces_uvm-1.2
# #### solutions
# ##### lab6
# # N13-DDU
# ## N01-Base
# ## N06-UpPlan
# ## N09-DBlog
# ### N01-TianYa
# ### N03-BBlog
# #### N01-宝子信箱

# %% [markdown]
# all_md_li = []
# dir_set = set()  # 当前目录
# f_dir_set = set()  # 父目录
#
# for root, dirs, files in os.walk(file_dir):
#     root = root[15:].replace("\\", "/")
#
#     if ".git" not in root and "N02-ICB" not in root:
#         print(root)
#         if len(root.split("/")) == 1:
#             if root not in dir_set:
#                 dir_set.add(root)
#                 if root:
#                     all_md_li.append("# " + root)
#                     f_dir_set.add("# " + root)
#         print(root)
#         for file in files:
#             if file not in ["readme.md", "README.md", "Readme.md"]:
#                 if os.path.splitext(file)[1] == '.' + "md":
#                     if root not in dir_set:
#                         dir_set.add(root)
#                         dir_tmp_li = root.split("/")
#
#                         print(dir_tmp_li)
#                         for i in range(len(dir_tmp_li)):
#                             tmp = "#" * (i + 1) + " " + dir_tmp_li[i]
#                             if tmp not in f_dir_set:
#                                 f_dir_set.add(tmp)
#                                 all_md_li.append(tmp)
# #                                 print(tmp)
#
#                     all_md_li.append("[📌 %s](%s)" % (os.path.splitext(file)[0], os.path.join(root, file).replace("\\", "/").replace(" ", "%20")))
