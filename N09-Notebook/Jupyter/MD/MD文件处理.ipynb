# %%
import os 
import shutil
import time
import datetime

# %% [markdown]
# # 文件夹整体迁移

# %%
# path = r"D:\Gitee\NLP" # 待迁移目录
# path_obj = r"D:\Gitee\MD\NLP"

# path = r"D:\Gitee\March\ML" # 待迁移目录
# path_obj = r"D:\Gitee\MD\ML"

# path = r"D:\Gitee\March\DL" # 待迁移目录
# path_obj = r"D:\Gitee\MD\DL"

# path = r"D:\Gitee\March\Python" # 待迁移目录
# path_obj = r"D:\Gitee\MD\Python"

# path = r"D:\Gitee\March\Base" # 待迁移目录
# path_obj = r"D:\Gitee\MD\Base"

# path = r"D:\Gitee\March\Math" # 待迁移目录
# path_obj = r"D:\Gitee\MD\Math"

# path = r"D:\Gitee\March\DA\数据分析笔记" # 待迁移目录
# path_obj = r"D:\Gitee\MD\数据分析"

# path = r"D:\Gitee\March\Java\Java_Basic_Introduction" # 待迁移目录
# path_obj = r"D:\Gitee\MD\Java_Basic"

path_images = r"D:\Gitee\Ehe\images" # 目标图片文件夹

# %% [markdown]
# ## 读取图片改名信息

# %%
import json

with open(r'D:\Gitee\March\images_dt.json', 'r', encoding='utf-8') as f:
    images_dt = json.load(f)

# %%
# images_dt

# %% [markdown]
# ## 生成图片改名信息及迁移

# %%
for root, dirs, files in os.walk(path):
    images_dt.setdefault(root, {})  # 文件夹路径

    if os.path.basename(root) == 'images':
        for file in files:
            time.sleep(0.001)  # 防止图片重名
            # 图片文件夹
            if file not in images_dt[os.path.dirname(root)]:
                print(">>> ", root, file)
                # 目标图片名
                image_name = os.path.basename(os.path.dirname(root)) + "-" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S-%f") + os.path.splitext(file)[-1]
                images_dt[os.path.dirname(root)][file] = image_name  # 保存图片改名信息

                # 复制图片到指定文件夹，并重新命名
                shutil.copyfile(os.path.join(root, file), os.path.join(path_images, image_name))

images_dt = {k: v for k, v in images_dt.items() if v}
# images_dt
# Out:
# >>>  D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\images 0
# >>>  D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\images 20150829005403871
# >>>  D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\images 20150829005703287
# >>>  D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\images 20150829010223059
# >>>  D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\images 640
# >>>  D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\images java.jpg
# >>>  D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\images 20150810204449423
# >>>  D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\images 20150828214536645

# %%
# for key in images_dt.keys():
#     print('\n',key,">>>")
#     for k, v in images_dt[key].items():
#         print("\t", k,'-->', v)

# %% [markdown]
# ## MD文件迁移

# %%
# 复制md文件
for root, dirs, files in os.walk(path):
    root_new = root.replace(path, path_obj) # 目标文件夹路径

    for file in files:
        # MD文件
        if os.path.splitext(file)[-1] == ".md" and file not in ['_contents.md']:
            if not os.path.exists(root_new): 
                # 新建目标文件夹
                os.makedirs(root_new)
                
            print(os.path.join(root, file), '>>>', os.path.join(root_new, file))
            shutil.copyfile(os.path.join(root, file), os.path.join(root_new, file))
# Out:
# D:\Gitee\March\Java\Java_Basic_Introduction\IT视频教程目录.md >>> D:\Gitee\MD\Java_Basic\IT视频教程目录.md
# D:\Gitee\March\Java\Java_Basic_Introduction\README.md >>> D:\Gitee\MD\Java_Basic\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\SUMMARY.md >>> D:\Gitee\MD\Java_Basic\SUMMARY.md
# D:\Gitee\March\Java\Java_Basic_Introduction\Apache Commons\commons.md >>> D:\Gitee\MD\Java_Basic\Apache Commons\commons.md
# D:\Gitee\March\Java\Java_Basic_Introduction\Guava\6-字符串处理：分割，连接，填充.md >>> D:\Gitee\MD\Java_Basic\Guava\6-字符串处理：分割，连接，填充.md
# D:\Gitee\March\Java\Java_Basic_Introduction\Guava\Google Guava使用指南.md >>> D:\Gitee\MD\Java_Basic\Guava\Google Guava使用指南.md
# D:\Gitee\March\Java\Java_Basic_Introduction\Guava\Java 代码性能优化.md >>> D:\Gitee\MD\Java_Basic\Guava\Java 代码性能优化.md
# D:\Gitee\March\Java\Java_Basic_Introduction\Node\node.md >>> D:\Gitee\MD\Java_Basic\Node\node.md
# D:\Gitee\March\Java\Java_Basic_Introduction\Node\RandomAccessFile.md >>> D:\Gitee\MD\Java_Basic\Node\RandomAccessFile.md
# D:\Gitee\March\Java\Java_Basic_Introduction\Node\内存管理.md >>> D:\Gitee\MD\Java_Basic\Node\内存管理.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第10章 反射机制\N01-类加载器.md >>> D:\Gitee\MD\Java_Basic\第10章 反射机制\N01-类加载器.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第10章 反射机制\N02-反射.md >>> D:\Gitee\MD\Java_Basic\第10章 反射机制\N02-反射.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第10章 反射机制\N03-Java反射.md >>> D:\Gitee\MD\Java_Basic\第10章 反射机制\N03-Java反射.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第10章 反射机制\N04-注解.md >>> D:\Gitee\MD\Java_Basic\第10章 反射机制\N04-注解.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第10章 反射机制\N05-Java注解.md >>> D:\Gitee\MD\Java_Basic\第10章 反射机制\N05-Java注解.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第10章 反射机制\N06-Java注解Annotation基础.md >>> D:\Gitee\MD\Java_Basic\第10章 反射机制\N06-Java注解Annotation基础.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第10章 反射机制\N07-基础篇：带你从头到尾玩转注解.md >>> D:\Gitee\MD\Java_Basic\第10章 反射机制\N07-基础篇：带你从头到尾玩转注解.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第10章 反射机制\N08-Annotation-Processing-Tool详解.md >>> D:\Gitee\MD\Java_Basic\第10章 反射机制\N08-Annotation-Processing-Tool详解.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第10章 反射机制\N09-依赖注入.md >>> D:\Gitee\MD\Java_Basic\第10章 反射机制\N09-依赖注入.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第10章 反射机制\N10-动态代理.md >>> D:\Gitee\MD\Java_Basic\第10章 反射机制\N10-动态代理.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第10章 反射机制\N11-Java动态代理.md >>> D:\Gitee\MD\Java_Basic\第10章 反射机制\N11-Java动态代理.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第10章 反射机制\README.md >>> D:\Gitee\MD\Java_Basic\第10章 反射机制\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第11章 新特性\N01-JDK新特性.md >>> D:\Gitee\MD\Java_Basic\第11章 新特性\N01-JDK新特性.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第11章 新特性\N02-泛型基础1.md >>> D:\Gitee\MD\Java_Basic\第11章 新特性\N02-泛型基础1.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第11章 新特性\N03-泛型基础2.md >>> D:\Gitee\MD\Java_Basic\第11章 新特性\N03-泛型基础2.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第11章 新特性\N04-泛型封装.md >>> D:\Gitee\MD\Java_Basic\第11章 新特性\N04-泛型封装.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第11章 新特性\N05-你应该更新的Java知识.md >>> D:\Gitee\MD\Java_Basic\第11章 新特性\N05-你应该更新的Java知识.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第11章 新特性\N06-你应该更新的Java知识之常用程序库1.md >>> D:\Gitee\MD\Java_Basic\第11章 新特性\N06-你应该更新的Java知识之常用程序库1.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第11章 新特性\N07-你应该更新的Java知识之常用程序库2.md >>> D:\Gitee\MD\Java_Basic\第11章 新特性\N07-你应该更新的Java知识之常用程序库2.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第11章 新特性\N08-你应该更新的Java知识之Observer.md >>> D:\Gitee\MD\Java_Basic\第11章 新特性\N08-你应该更新的Java知识之Observer.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第11章 新特性\N09-Google Guava官方教程.md >>> D:\Gitee\MD\Java_Basic\第11章 新特性\N09-Google Guava官方教程.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第11章 新特性\N10-Google Guava官方教程2.md >>> D:\Gitee\MD\Java_Basic\第11章 新特性\N10-Google Guava官方教程2.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第11章 新特性\N11-Lambda表达式.md >>> D:\Gitee\MD\Java_Basic\第11章 新特性\N11-Lambda表达式.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第11章 新特性\N12-Java8的十大新特性.md >>> D:\Gitee\MD\Java_Basic\第11章 新特性\N12-Java8的十大新特性.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第11章 新特性\README.md >>> D:\Gitee\MD\Java_Basic\第11章 新特性\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第12章 内存管理\N01-JVM 内存模型 Stack Heap.md >>> D:\Gitee\MD\Java_Basic\第12章 内存管理\N01-JVM 内存模型 Stack Heap.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第12章 内存管理\README.md >>> D:\Gitee\MD\Java_Basic\第12章 内存管理\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第13章 GUI\README.md >>> D:\Gitee\MD\Java_Basic\第13章 GUI\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第1章 Java开发入门\N01-Java概述.md >>> D:\Gitee\MD\Java_Basic\第1章 Java开发入门\N01-Java概述.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第1章 Java开发入门\N02-JDK、JRE、JVM的区别与联系.md >>> D:\Gitee\MD\Java_Basic\第1章 Java开发入门\N02-JDK、JRE、JVM的区别与联系.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第1章 Java开发入门\README.md >>> D:\Gitee\MD\Java_Basic\第1章 Java开发入门\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\N01-Java语法基础-1.md >>> D:\Gitee\MD\Java_Basic\第2章 Java编程基础\N01-Java语法基础-1.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\N02-Java语法基础-2.md >>> D:\Gitee\MD\Java_Basic\第2章 Java编程基础\N02-Java语法基础-2.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\N03-基本数据类型包装类.md >>> D:\Gitee\MD\Java_Basic\第2章 Java编程基础\N03-基本数据类型包装类.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\N04-阿里巴巴Java开发手册.md >>> D:\Gitee\MD\Java_Basic\第2章 Java编程基础\N04-阿里巴巴Java开发手册.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\N05-阿里 Java 开发手册最新完美版，千锤百炼始出炉.md >>> D:\Gitee\MD\Java_Basic\第2章 Java编程基础\N05-阿里 Java 开发手册最新完美版，千锤百炼始出炉.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\N06-阿里《Java开发手册》终极版！.md >>> D:\Gitee\MD\Java_Basic\第2章 Java编程基础\N06-阿里《Java开发手册》终极版！.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\N07-Google Java编程风格指南.md >>> D:\Gitee\MD\Java_Basic\第2章 Java编程基础\N07-Google Java编程风格指南.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\N08-详细介绍JAVA和C++区别.md >>> D:\Gitee\MD\Java_Basic\第2章 Java编程基础\N08-详细介绍JAVA和C++区别.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\N09-什么是堆和栈，它们在哪儿？.md >>> D:\Gitee\MD\Java_Basic\第2章 Java编程基础\N09-什么是堆和栈，它们在哪儿？.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\N10-引用、指针和句柄的区别.md >>> D:\Gitee\MD\Java_Basic\第2章 Java编程基础\N10-引用、指针和句柄的区别.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\N11-Java与指针.md >>> D:\Gitee\MD\Java_Basic\第2章 Java编程基础\N11-Java与指针.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\N12-Java程序员必读的书籍.md >>> D:\Gitee\MD\Java_Basic\第2章 Java编程基础\N12-Java程序员必读的书籍.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础\README.md >>> D:\Gitee\MD\Java_Basic\第2章 Java编程基础\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N01-数组工具类.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N01-数组工具类.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N02-文档注释.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N02-文档注释.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N03-面向对象.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N03-面向对象.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N04-Object类.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N04-Object类.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N05-单例设计模式.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N05-单例设计模式.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N06-封装.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N06-封装.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N07-继承.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N07-继承.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N08-多态.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N08-多态.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N09-抽象类与接口.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N09-抽象类与接口.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N10-接口回调.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N10-接口回调.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N11-内部类.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N11-内部类.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N12-异常.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N12-异常.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N13-对象的深复制和浅复制.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N13-对象的深复制和浅复制.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N14-java内存模型.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N14-java内存模型.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N15-闭包.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N15-闭包.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N16-垃圾回收机制.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N16-垃圾回收机制.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\N17-深度思考Java成员变量的初始化.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\N17-深度思考Java成员变量的初始化.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象\README.md >>> D:\Gitee\MD\Java_Basic\第3章 面向对象\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第4章 常见对象\N01-String类.md >>> D:\Gitee\MD\Java_Basic\第4章 常见对象\N01-String类.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第4章 常见对象\N02-正则表达式基础.md >>> D:\Gitee\MD\Java_Basic\第4章 常见对象\N02-正则表达式基础.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第4章 常见对象\N03-正则表达式的应用.md >>> D:\Gitee\MD\Java_Basic\第4章 常见对象\N03-正则表达式的应用.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第4章 常见对象\N04-常用正则表达式.md >>> D:\Gitee\MD\Java_Basic\第4章 常见对象\N04-常用正则表达式.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第4章 常见对象\N05-字符串格式化.md >>> D:\Gitee\MD\Java_Basic\第4章 常见对象\N05-字符串格式化.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第4章 常见对象\N06-System类和Runtime类.md >>> D:\Gitee\MD\Java_Basic\第4章 常见对象\N06-System类和Runtime类.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第4章 常见对象\N07-Math类和Random类.md >>> D:\Gitee\MD\Java_Basic\第4章 常见对象\N07-Math类和Random类.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第4章 常见对象\README.md >>> D:\Gitee\MD\Java_Basic\第4章 常见对象\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第4章 常见对象\regex.md >>> D:\Gitee\MD\Java_Basic\第4章 常见对象\regex.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第4章 常见对象\分组替换.md >>> D:\Gitee\MD\Java_Basic\第4章 常见对象\分组替换.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第4章 常见对象\常见对象.md >>> D:\Gitee\MD\Java_Basic\第4章 常见对象\常见对象.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第4章 常见对象\格式化.md >>> D:\Gitee\MD\Java_Basic\第4章 常见对象\格式化.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\Fork_Join框架介绍.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\Fork_Join框架介绍.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\Java中的Runnable、Callable、Future、FutureTask的区别与示例.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\Java中的Runnable、Callable、Future、FutureTask的区别与示例.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\Java并发工具包concurrent用户指南.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\Java并发工具包concurrent用户指南.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N01-多线程.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N01-多线程.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N02-线程池.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N02-线程池.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N03-volatile关键字解析.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N03-volatile关键字解析.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N04-HandlerThread.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N04-HandlerThread.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N05-Callable和Future.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N05-Callable和Future.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N06-Java程序死锁问题原理及解决方案.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N06-Java程序死锁问题原理及解决方案.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N07-线程锁技术.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N07-线程锁技术.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N08-定时器、互斥、同步通信技术.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N08-定时器、互斥、同步通信技术.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N09-线程范围内共享数据.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N09-线程范围内共享数据.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N10-多个线程之间共享数据的方式探讨.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N10-多个线程之间共享数据的方式探讨.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N11-使用JDK5中同步技术的3个面试题.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N11-使用JDK5中同步技术的3个面试题.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N12-同步工具类.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N12-同步工具类.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N13-原子类.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N13-原子类.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N14-集合及concurrent并发包总结.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N14-集合及concurrent并发包总结.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\N15-JDK8对并发的新支持.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\N15-JDK8对并发的新支持.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\README.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\什么时候使用CountDownLatch.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\什么时候使用CountDownLatch.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\多线程问题总结.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\多线程问题总结.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\线程池2.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\线程池2.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程\阻塞队列.md >>> D:\Gitee\MD\Java_Basic\第5章 多线程\阻塞队列.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N01-Collection接口.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N01-Collection接口.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N02-List接口.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N02-List接口.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N03-Set接口.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N03-Set接口.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N04-Queue接口.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N04-Queue接口.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N05-集合的遍历.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N05-集合的遍历.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N06-集合工具类.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N06-集合工具类.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N07-Map接口.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N07-Map接口.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N08-Predicate和Stream操作集合.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N08-Predicate和Stream操作集合.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N09-集合框架的综合应用.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N09-集合框架的综合应用.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N10-Java集合类型详解.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N10-Java集合类型详解.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N11-LinkedList源码剖析.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N11-LinkedList源码剖析.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N12-LinkedHashMap源码剖析.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N12-LinkedHashMap源码剖析.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N13-HashMap、哈希表、哈希函数.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N13-HashMap、哈希表、哈希函数.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N14-HashMap的实现原理.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N14-HashMap的实现原理.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\N15-HashMap源码剖析.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\N15-HashMap源码剖析.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\README.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\线程安全的集合.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\线程安全的集合.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\集合框架2.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\集合框架2.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第6章 集合框架\高效集合.md >>> D:\Gitee\MD\Java_Basic\第6章 集合框架\高效集合.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流\N01-IO流之File类.md >>> D:\Gitee\MD\Java_Basic\第7章 IO流\N01-IO流之File类.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流\N02-IO流之字节流.md >>> D:\Gitee\MD\Java_Basic\第7章 IO流\N02-IO流之字节流.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流\N03-IO流之字符流.md >>> D:\Gitee\MD\Java_Basic\第7章 IO流\N03-IO流之字符流.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流\N04-常用IO流.md >>> D:\Gitee\MD\Java_Basic\第7章 IO流\N04-常用IO流.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流\N05-NIO.md >>> D:\Gitee\MD\Java_Basic\第7章 IO流\N05-NIO.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流\N06-AIO.md >>> D:\Gitee\MD\Java_Basic\第7章 IO流\N06-AIO.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流\N07-NIO和AIO.md >>> D:\Gitee\MD\Java_Basic\第7章 IO流\N07-NIO和AIO.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流\NIO工具类.md >>> D:\Gitee\MD\Java_Basic\第7章 IO流\NIO工具类.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流\README.md >>> D:\Gitee\MD\Java_Basic\第7章 IO流\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流\对象的深复制和浅复制.md >>> D:\Gitee\MD\Java_Basic\第7章 IO流\对象的深复制和浅复制.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流\序列化流.md >>> D:\Gitee\MD\Java_Basic\第7章 IO流\序列化流.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流\通过mark和reset方法重复利用InputStream.md >>> D:\Gitee\MD\Java_Basic\第7章 IO流\通过mark和reset方法重复利用InputStream.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程\N01-网络编程.md >>> D:\Gitee\MD\Java_Basic\第8章 网络编程\N01-网络编程.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程\N02-写给那些让我糊里糊涂的HTTP、TCP、UDP、Socket.md >>> D:\Gitee\MD\Java_Basic\第8章 网络编程\N02-写给那些让我糊里糊涂的HTTP、TCP、UDP、Socket.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程\N03-你应该知道的计算机网络知识.md >>> D:\Gitee\MD\Java_Basic\第8章 网络编程\N03-你应该知道的计算机网络知识.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程\README.md >>> D:\Gitee\MD\Java_Basic\第8章 网络编程\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第9章 安全加密\base64.md >>> D:\Gitee\MD\Java_Basic\第9章 安全加密\base64.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第9章 安全加密\N01-和安全有关的那些事.md >>> D:\Gitee\MD\Java_Basic\第9章 安全加密\N01-和安全有关的那些事.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第9章 安全加密\N02-对称加密.md >>> D:\Gitee\MD\Java_Basic\第9章 安全加密\N02-对称加密.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第9章 安全加密\N03-非对称加密.md >>> D:\Gitee\MD\Java_Basic\第9章 安全加密\N03-非对称加密.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第9章 安全加密\N04-消息摘要MessageDigest.md >>> D:\Gitee\MD\Java_Basic\第9章 安全加密\N04-消息摘要MessageDigest.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第9章 安全加密\N05-数字签名和数字证书.md >>> D:\Gitee\MD\Java_Basic\第9章 安全加密\N05-数字签名和数字证书.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第9章 安全加密\N06-Https扫盲贴.md >>> D:\Gitee\MD\Java_Basic\第9章 安全加密\N06-Https扫盲贴.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第9章 安全加密\N07-Https编程.md >>> D:\Gitee\MD\Java_Basic\第9章 安全加密\N07-Https编程.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第9章 安全加密\README.md >>> D:\Gitee\MD\Java_Basic\第9章 安全加密\README.md
# D:\Gitee\March\Java\Java_Basic_Introduction\第9章 安全加密\网络安全.md >>> D:\Gitee\MD\Java_Basic\第9章 安全加密\网络安全.md

# %% [markdown]
# ## 修改图片插入来源

# %%
# 修改图片插入信息
for root, dirs, files in os.walk(path_obj):
    if os.path.basename(root) not in ['.ipynb_checkpoints']:
        for file in files:
            if os.path.splitext(file)[-1] == ".md":
                file_path = os.path.join(root, file)

                string_all = open(file_path, 'r', encoding='utf-8').readlines()
                # 去掉开头的空格
                # string_all = [line.lstrip() if len(line) > 1 else '\n' for line in string_all]

                for i in range(len(string_all)):
                    if 'images' in string_all[
                            i] and 'liuhuihe' not in string_all[i]:
                        tmp_str = string_all[i]
                        # md文件所在目录，替换成图片原始位置所在目录
                        root_dt = root.replace(path_obj, path)

                        if "]" in tmp_str:
                            N1, N2 = tmp_str.find("!["), tmp_str.find(")")
                            obg_str = tmp_str[N1:N2 + 1]
                            N = obg_str.find("images/") + 7
                            images_name = obg_str[N:-1]
                            tmp_str = tmp_str[:
                                              N1] + "![](images/" + images_name + ")" + tmp_str[
                                                  N2 + 1:]

                        if "<" in tmp_str:
                            N1, N2 = tmp_str.find("<"), tmp_str.find(">")
                            obg_str = tmp_str[N1:N2 + 1].replace('"', " ")
                            N = obg_str.find("images/") + 7
                            images_name = obg_str[N:obg_str.find(" ", N)]
                            tmp_str = tmp_str[:
                                              N1] + "![](images/" + images_name + ")" + tmp_str[
                                                  N2 + 1:]

                        try:
                            # 替换图片名
                            tmp_str = tmp_str.replace(
                                images_name, images_dt[root_dt][images_name])
                            # 替换图片来源
                            tmp_str = tmp_str.replace(
                                './images', 'images'
                            ).replace(
                                'images/',
                                'https://gitee.com/liuhuihe/Ehe/raw/master/images/'
                            )
                            string_all[i] = tmp_str
                        except Exception as e:
                            print(e)
                            print(root_dt, file)
                            print(">>>", tmp_str)

                open(file_path, 'w', encoding='utf-8').writelines(string_all)
# Out:
# 'jvm内存10.png'
# D:\Gitee\March\Java\Java_Basic_Introduction\第1章 Java开发入门 N01-Java概述.md
# >>> typora-copy-images-to: img
#
# 'jvm3.png'
# D:\Gitee\March\Java\Java_Basic_Introduction\第2章 Java编程基础 N01-Java语法基础-1.md
# >>> typora-copy-images-to: images
#
# 'java_book_27.png'
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象 N01-数组工具类.md
# >>> typora-copy-images-to: img
#
# 'clone1.png'
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象 N13-对象的深复制和浅复制.md
# >>> ![](images/clone1.png)
#
# 'clone2.png'
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象 N13-对象的深复制和浅复制.md
# >>> ![](images/clone2.png)
#
# 'clone3.png'
# D:\Gitee\March\Java\Java_Basic_Introduction\第3章 面向对象 N13-对象的深复制和浅复制.md
# >>> ![](images/clone3.png)
# 'clone3.png'
# D:\Gitee\March\Java\Java_Basic_Introduction\第4章 常见对象 N01-String类.md
# >>> typora-copy-images-to: img
#
# '](http://images.cnitblog.com/blog/288799/201408/212219343783699.jpg'
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程 N03-volatile关键字解析.md
# >>> ![](images/](http://images.cnitblog.com/blog/288799/201408/212219343783699.jpg)
#
# '(http://images.cnitblog.com/blog/288799/201408/212305263939989.jpg'
# D:\Gitee\March\Java\Java_Basic_Introduction\第5章 多线程 N03-volatile关键字解析.md
# >>> ![](images/(http://images.cnitblog.com/blog/288799/201408/212305263939989.jpg)
#
# '集合框架.png'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N01-IO流之File类.md
# >>> typora-copy-images-to: img
#
# '](http://img.blog.csdn.net/20161003130057678'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N02-IO流之字节流.md
# >>> ![](images/](http://img.blog.csdn.net/20161003130057678)
#
# '](http://img.blog.csdn.net/20161003130057678'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N02-IO流之字节流.md
# >>> # 2. images/概述
#
# '](http://img.blog.csdn.net/20161003130057678'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N02-IO流之字节流.md
# >>> 大多数应用程序都需要实现与设备之间的数据传输，例如键盘可以输入数据，显示器可以显示程序的运行结果等。在Java中，将这种通过不同输入输出设备（键盘，内存，显示器，网络等）之间的数据传输抽象的表述为“流”，程序允许通过流的方式与输入输出设备进行数据传输。Java中的“流”都位于Java.io包中，称之为IO（输入输出）流。 images/：即InputOutput的缩写。
#
# '](http://img.blog.csdn.net/20161003130057678'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N02-IO流之字节流.md
# >>> images/的特点：
#
# '](http://img.blog.csdn.net/20161003130057678'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N02-IO流之字节流.md
# >>> - images/用来处理设备间的数据传输。
#
# '.png'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N02-IO流之字节流.md
# >>> ![](images/.png)
#
# '.png'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N02-IO流之字节流.md
# >>>  images/的常用基类：
#
# '](http://img.blog.csdn.net/20150827230436781'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N02-IO流之字节流.md
# >>> ![](images/](http://img.blog.csdn.net/20150827230436781)
#
# '](http://img.blog.csdn.net/20150827230338538'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N02-IO流之字节流.md
# >>> ![](images/](http://img.blog.csdn.net/20150827230338538)
#
# '](http://img.blog.csdn.net/20150827230507625'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N02-IO流之字节流.md
# >>> ![](images/](http://img.blog.csdn.net/20150827230507625)
#
# '](http://img.blog.csdn.net/20150827230507625'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N02-IO流之字节流.md
# >>> 在计算机中，无论是文本、图片、音频还是视频，所有文件都是以二进制(字节)形式存在的，images/中针对字节的输入输出提供了一系列的流，统称为字节流。字节流是程序中最常用的流，根据数据的传输方向可将其分为字节输入流和字节输出流。在JDK中，提供了两个抽象类InputStream和OutputStream，它们是字节流的顶级父类，所有的字节输入流都继承自InputStream，所有的字节输出流都继承自OutputStream。为了方便理解，可以把InputStream和OutputStream比作两根“水管”，如图所示。
#
# '](http://img.blog.csdn.net/20150915111705070'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N02-IO流之字节流.md
# >>> ![](images/](http://img.blog.csdn.net/20150915111705070)
#
# '](http://img.blog.csdn.net/20150915111743638'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N02-IO流之字节流.md
# >>> ![](images/](http://img.blog.csdn.net/20150915111743638)
#
# '](http://img.blog.csdn.net/20150812155310074'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N03-IO流之字符流.md
# >>> ![](images/](http://img.blog.csdn.net/20150812155310074)
#
# '](http://img.blog.csdn.net/20150812155310074'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N03-IO流之字符流.md
# >>> images/可分为字节流和字符流，有时字节流和字符流之间也需要进行转换。在JDK中提供了两个类可以将字节流转换为字符流，它们分别是InputStreamReader和OutputStreamWriter。
#
# '](http://img.blog.csdn.net/20150915111452739'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N03-IO流之字符流.md
# >>> ![](images/](http://img.blog.csdn.net/20150915111452739)
#
# '](http://img.blog.csdn.net/20150915111611235'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N03-IO流之字符流.md
# >>> ![](images/](http://img.blog.csdn.net/20150915111611235)
#
# '](http://img.blog.csdn.net/20150915111939505'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N03-IO流之字符流.md
# >>> ![](images/](http://img.blog.csdn.net/20150915111939505)
#
# '](http://img.blog.csdn.net/20150915112037930'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N03-IO流之字符流.md
# >>> ![](images/](http://img.blog.csdn.net/20150915112037930)
#
# '](http://img.blog.csdn.net/20150915112318443'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N03-IO流之字符流.md
# >>> ![](images/](http://img.blog.csdn.net/20150915112318443)
#
# '](http://img.blog.csdn.net/20150915112318443'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N03-IO流之字符流.md
# >>> ![](images/](http://img.blog.csdn.net/20150915112318443)
#
# '](http://img.blog.csdn.net/20150915112441236'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N03-IO流之字符流.md
# >>> ![](images/](http://img.blog.csdn.net/20150915112441236)
#
# '](http://img.blog.csdn.net/20150915112520875'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N03-IO流之字符流.md
# >>> ![](images/](http://img.blog.csdn.net/20150915112520875)
#
# '](http://img.blog.csdn.net/20150827230556993'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N03-IO流之字符流.md
# >>> ![](images/](http://img.blog.csdn.net/20150827230556993)
#
# '](http://img.blog.csdn.net/20150812142557398'
# D:\Gitee\March\Java\Java_Basic_Introduction\第7章 IO流 N03-IO流之字符流.md
# >>> ![](images/](http://img.blog.csdn.net/20150812142557398)
# 'tp://images.cnblogs.com/cnblogs_com/goodcandle/socket2.jpg'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N02-写给那些让我糊里糊涂的HTTP、TCP、UDP、Socket.md
# >>> ![](images/tp://images.cnblogs.com/cnblogs_com/goodcandle/socket2.jpg)
#
# '、TCP、UDP、Socket](http://images.cnblogs.com/cnblogs_com/goodcandle/socket2.jpg'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N02-写给那些让我糊里糊涂的HTTP、TCP、UDP、Socket.md
# >>> ![](images/、TCP、UDP、Socket](http://images.cnblogs.com/cnblogs_com/goodcandle/socket2.jpg)
#
# '1862021-af0d51bb67056756.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-af0d51bb67056756.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-f1afe05e3f977bc0.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-f1afe05e3f977bc0.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-bf19cb99d215d612.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-bf19cb99d215d612.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-874c57c6fef66e14.gif?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-874c57c6fef66e14.gif?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-7dde2164f6cf4909.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-7dde2164f6cf4909.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-46f78943bbcf3e24.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-46f78943bbcf3e24.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-e6047a66dbe9b8da.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-e6047a66dbe9b8da.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-8f226562cb4660b7.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-8f226562cb4660b7.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-efbd48ddb35f6a5e.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-efbd48ddb35f6a5e.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-96ebb99a0ddcdbcb.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-96ebb99a0ddcdbcb.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-c239230611b6f022.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-c239230611b6f022.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-30ba250cb0fa9b7e.jpeg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-30ba250cb0fa9b7e.jpeg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-e1c5e50f9b13f95d.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-e1c5e50f9b13f95d.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-88c61e35ef146d04.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-88c61e35ef146d04.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-eecef2ac6d28c7e8.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-eecef2ac6d28c7e8.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-0024d3be9cf88822.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-0024d3be9cf88822.jpg?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)
#
# '1862021-caefad90e9a67824.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240'
# D:\Gitee\March\Java\Java_Basic_Introduction\第8章 网络编程 N03-你应该知道的计算机网络知识.md
# >>> ![](images/1862021-caefad90e9a67824.png?imageMogr2/auto-orient/strip%7CimageView2/2/w/1240)

# %% [markdown]
# ## 图片改名信息存入本地

# %%
import json

images_js = json.dumps(images_dt, indent=4)
with open(r'D:\Gitee\March\images_dt.json', 'w', encoding='utf-8') as f:
    f.write(images_js)
