# %%
import os
import requests
import json
import time
import numpy as np
import pandas as pd
from pprint import pprint
import datetime

# %%
yesterday = (datetime.datetime.now() - datetime.timedelta(days=1)).strftime('%Y%m%d')
yesterday
# Out:
# '20230207'

# %%
today = datetime.datetime.now().strftime('%Y%m%d')
today
# Out:
# '20230208'

# %%
# time_stamp = time.time()    #取出时间戳
# time_stamp = int(time_stamp*1000)   #将10位整数变为13位整数
# print(time_stamp)
# page = 10 #input("请输入你想要爬取的页数:")


# # url = 'http://41.push2.eastmoney.com/api/qt/clist/get'
# url = 'http://71.push2.eastmoney.com/api/qt/clist/get?'
headers = {
    'Referer':
    'http://quote.eastmoney.com/',
    'User-Agent':
    'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.146 Safari/537.36'
}

# #这个参数列表
# datas = {
#     'cb': f'jQuery112403210602285843305_{time_stamp}',
#     'pn': f'{page}',
#     'pz': '20',
#     'po': '1',
#     'np': '1',
#     'ut': 'bd1d9ddb04089700cf9c27f6f7426281',
#     'fltt': '2',
#     'invt': '2',
#     'fid': 'f3',
#     'fs': 'm:1 s:2',
#     'fields':
#     'f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f12,f13,f14,f15,f16,f17,f18,f20,f21,f23,f24,f25,f22,f11,f62,f128,f136,f115,f152',
#     '_': f'{time_stamp}'
# }

# %% [markdown]
# # 爬取今天数据

# %%
# url = """http://71.push2.eastmoney.com/api/qt/clist/get?cb=jQuery112403210602285843305_1675345303710&pn=%s&pz=20&po=1&np=1&ut=bd1d9ddb04089700cf9c27f6f7426281&fltt=2&invt=2&wbp2u=|0|0|0|web&fid=f3&fs=m:0+t:6,m:0+t:80,m:1+t:2,m:1+t:23,m:0+t:81+s:2048&fields=f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f12,f13,f14,f15,f16,f17,f18,f20,f21,f23,f24,f25,f22,f11,f62,f128,f136,f115,f152&_=1675345303757"""

# %%
url = """http://11.push2.eastmoney.com/api/qt/clist/get?cb=jQuery1124045425929349494565_1675652972800&pn=%s&pz=20&po=1&np=1&ut=bd1d9ddb04089700cf9c27f6f7426281&fltt=2&invt=2&wbp2u=5556335897207406|0|0|0|web&fid=f3&fs=m:0+t:6,m:0+t:80,m:1+t:2,m:1+t:23,m:0+t:81+s:2048&fields=f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f12,f13,f14,f15,f16,f17,f18,f20,f21,f23,f24,f25,f22,f11,f62,f128,f136,f115,f152&_=1675652972804"""

# %%
def get_data_pn(url, pn):
    url = url % pn
    # print(url)
    # jsondata = requests.get(url=url, headers=headers, params=datas).text  # 输出文本
    jsondata = requests.get(url=url, headers=headers).text  # 输出文本

    data_pn_li = []
    start_data = jsondata.index('{"rc":0,')  # 取出前面文本
    end_data = jsondata.index('}]}}') + len('}]}}')  # 取出后面文本
    for json_data in json.loads(jsondata[start_data:end_data])['data']['diff']:
        info_tmp = []
        info_tmp.append(json_data['f12'])  # 名称
        info_tmp.append(json_data['f14'])  # 代码
        info_tmp.append(json_data['f2'])  # 最新价
        info_tmp.append(json_data['f17'])  # 今开
        info_tmp.append(json_data['f18'])  # 昨收
        # info_tmp.append(json_data['f15'])  # 最高
        # info_tmp.append(json_data['f16'])  # 最低
        # info_tmp.append(json_data['f8'])  # 换手率
        # info_tmp.append(json_data['f23'])  # 市净率
        data_pn_li.append(info_tmp)
    return data_pn_li

# %%
# data_all_li

# %%
data_res_file = "data/all_data_%s.json" % today
if not os.path.exists(data_res_file):
    print(">>>初始化结果文件")
    pn_li = [pn for pn in range(1, 265)]
    data_pn_res = []

    all_data_json = {}
    all_data_json["pn"] = pn_li
    all_data_json['data'] = data_pn_res
    json.dump(all_data_json, open(data_res_file, "w", encoding="utf-8"))
else:
    print(">>>读取结果数据")
    all_data_json = json.load(open(data_res_file, "r", encoding="utf-8"))
    pn_li = all_data_json["pn"]
    data_pn_res = all_data_json['data']
# Out:
# >>>初始化结果文件

# %%
pn_per = []
for pn in pn_li:
    try:
        time.sleep(0.2)
        print(">>> 正在处理第%s页" % pn)
        data_pn_tmp = get_data_pn(url, pn)
        pn_per.append(pn)
        data_pn_res.extend(data_pn_tmp)
    except Exception as e:
        print(">>> 异常", pn, e)
        all_data_json["pn"] = list(set(pn_li) - set(pn_per))
        all_data_json["data"] = data_pn_res
        json.dump(all_data_json, open(data_res_file, "w", encoding="utf-8"))

print("任务完成".center(20, "*"))
all_data_json["pn"] = list(set(pn_li) - set(pn_per))
all_data_json["data"] = data_pn_res
json.dump(all_data_json, open(data_res_file, "w", encoding="utf-8"))
# Out:
# >>> 正在处理第1页
# >>> 正在处理第2页
# >>> 正在处理第3页
# >>> 正在处理第4页
# >>> 正在处理第5页
# >>> 正在处理第6页
# >>> 正在处理第7页
# >>> 正在处理第8页
# >>> 正在处理第9页
# >>> 正在处理第10页
# >>> 正在处理第11页
# >>> 正在处理第12页
# >>> 正在处理第13页
# >>> 正在处理第14页
# >>> 正在处理第15页
# >>> 正在处理第16页
# >>> 正在处理第17页
# >>> 正在处理第18页
# >>> 正在处理第19页
# >>> 正在处理第20页
# >>> 正在处理第21页
# >>> 正在处理第22页
# >>> 正在处理第23页
# >>> 正在处理第24页
# >>> 正在处理第25页
# >>> 正在处理第26页
# >>> 正在处理第27页
# >>> 正在处理第28页
# >>> 正在处理第29页
# >>> 正在处理第30页
# >>> 正在处理第31页
# >>> 正在处理第32页
# >>> 正在处理第33页
# >>> 正在处理第34页
# >>> 正在处理第35页
# >>> 正在处理第36页
# >>> 正在处理第37页
# >>> 正在处理第38页
# >>> 正在处理第39页
# >>> 正在处理第40页
# >>> 正在处理第41页
# >>> 正在处理第42页
# >>> 正在处理第43页
# >>> 正在处理第44页
# >>> 正在处理第45页
# >>> 正在处理第46页
# >>> 正在处理第47页
# >>> 正在处理第48页
# >>> 正在处理第49页
# >>> 正在处理第50页
# >>> 正在处理第51页
# >>> 正在处理第52页
# >>> 正在处理第53页
# >>> 正在处理第54页
# >>> 正在处理第55页
# >>> 正在处理第56页
# >>> 正在处理第57页
# >>> 正在处理第58页
# >>> 正在处理第59页
# >>> 正在处理第60页
# >>> 正在处理第61页
# >>> 正在处理第62页
# >>> 正在处理第63页
# >>> 正在处理第64页
# >>> 正在处理第65页
# >>> 正在处理第66页
# >>> 正在处理第67页
# >>> 正在处理第68页
# >>> 正在处理第69页
# >>> 正在处理第70页
# >>> 正在处理第71页
# >>> 正在处理第72页
# >>> 正在处理第73页
# >>> 正在处理第74页
# >>> 正在处理第75页
# >>> 正在处理第76页
# >>> 正在处理第77页
# >>> 正在处理第78页
# >>> 正在处理第79页
# >>> 正在处理第80页
# >>> 正在处理第81页
# >>> 正在处理第82页
# >>> 正在处理第83页
# >>> 正在处理第84页
# >>> 正在处理第85页
# >>> 正在处理第86页
# >>> 正在处理第87页
# >>> 正在处理第88页
# >>> 正在处理第89页
# >>> 正在处理第90页
# >>> 正在处理第91页
# >>> 正在处理第92页
# >>> 正在处理第93页
# >>> 正在处理第94页
# >>> 正在处理第95页
# >>> 正在处理第96页
# >>> 正在处理第97页
# >>> 正在处理第98页
# >>> 正在处理第99页
# >>> 正在处理第100页
# >>> 正在处理第101页
# >>> 正在处理第102页
# >>> 正在处理第103页
# >>> 正在处理第104页
# >>> 正在处理第105页
# >>> 正在处理第106页
# >>> 正在处理第107页
# >>> 正在处理第108页
# >>> 正在处理第109页
# >>> 正在处理第110页
# >>> 正在处理第111页
# >>> 正在处理第112页
# >>> 正在处理第113页
# >>> 正在处理第114页
# >>> 正在处理第115页
# >>> 正在处理第116页
# >>> 正在处理第117页
# >>> 正在处理第118页
# >>> 正在处理第119页
# >>> 正在处理第120页
# >>> 正在处理第121页
# >>> 正在处理第122页
# >>> 正在处理第123页
# >>> 正在处理第124页
# >>> 正在处理第125页
# >>> 正在处理第126页
# >>> 正在处理第127页
# >>> 正在处理第128页
# >>> 正在处理第129页
# >>> 正在处理第130页
# >>> 正在处理第131页
# >>> 正在处理第132页
# >>> 正在处理第133页
# >>> 正在处理第134页
# >>> 正在处理第135页
# >>> 正在处理第136页
# >>> 正在处理第137页
# >>> 正在处理第138页
# >>> 正在处理第139页
# >>> 正在处理第140页
# >>> 正在处理第141页
# >>> 正在处理第142页
# >>> 正在处理第143页
# >>> 正在处理第144页
# >>> 正在处理第145页
# >>> 正在处理第146页
# >>> 正在处理第147页
# >>> 正在处理第148页
# >>> 正在处理第149页
# >>> 正在处理第150页
# >>> 正在处理第151页
# >>> 正在处理第152页
# >>> 正在处理第153页
# >>> 正在处理第154页
# >>> 正在处理第155页
# >>> 正在处理第156页
# >>> 正在处理第157页
# >>> 正在处理第158页
# >>> 正在处理第159页
# >>> 正在处理第160页
# >>> 正在处理第161页
# >>> 正在处理第162页
# >>> 正在处理第163页
# >>> 正在处理第164页
# >>> 正在处理第165页
# >>> 正在处理第166页
# >>> 正在处理第167页
# >>> 正在处理第168页
# >>> 正在处理第169页
# >>> 正在处理第170页
# >>> 正在处理第171页
# >>> 正在处理第172页
# >>> 正在处理第173页
# >>> 正在处理第174页
# >>> 正在处理第175页
# >>> 正在处理第176页
# >>> 正在处理第177页
# >>> 正在处理第178页
# >>> 正在处理第179页
# >>> 正在处理第180页
# >>> 正在处理第181页
# >>> 正在处理第182页
# >>> 正在处理第183页
# >>> 正在处理第184页
# >>> 正在处理第185页
# >>> 正在处理第186页
# >>> 正在处理第187页
# >>> 正在处理第188页
# >>> 正在处理第189页
# >>> 正在处理第190页
# >>> 正在处理第191页
# >>> 正在处理第192页
# >>> 正在处理第193页
# >>> 正在处理第194页
# >>> 正在处理第195页
# >>> 正在处理第196页
# >>> 正在处理第197页
# >>> 正在处理第198页
# >>> 正在处理第199页
# >>> 正在处理第200页
# >>> 正在处理第201页
# >>> 正在处理第202页
# >>> 正在处理第203页
# >>> 正在处理第204页
# >>> 正在处理第205页
# >>> 正在处理第206页
# >>> 正在处理第207页
# >>> 正在处理第208页
# >>> 正在处理第209页
# >>> 正在处理第210页
# >>> 正在处理第211页
# >>> 正在处理第212页
# >>> 正在处理第213页
# >>> 正在处理第214页
# >>> 正在处理第215页
# >>> 正在处理第216页
# >>> 正在处理第217页
# >>> 正在处理第218页
# >>> 正在处理第219页
# >>> 正在处理第220页
# >>> 正在处理第221页
# >>> 正在处理第222页
# >>> 正在处理第223页
# >>> 正在处理第224页
# >>> 正在处理第225页
# >>> 正在处理第226页
# >>> 正在处理第227页
# >>> 正在处理第228页
# >>> 正在处理第229页
# >>> 正在处理第230页
# >>> 正在处理第231页
# >>> 正在处理第232页
# >>> 正在处理第233页
# >>> 正在处理第234页
# >>> 正在处理第235页
# >>> 正在处理第236页
# >>> 正在处理第237页
# >>> 正在处理第238页
# >>> 正在处理第239页
# >>> 正在处理第240页
# >>> 正在处理第241页
# >>> 正在处理第242页
# >>> 正在处理第243页
# >>> 正在处理第244页
# >>> 正在处理第245页
# >>> 正在处理第246页
# >>> 正在处理第247页
# >>> 正在处理第248页
# >>> 正在处理第249页
# >>> 正在处理第250页
# >>> 正在处理第251页
# >>> 正在处理第252页
# >>> 正在处理第253页
# >>> 正在处理第254页
# >>> 正在处理第255页
# >>> 正在处理第256页
# >>> 正在处理第257页
# >>> 正在处理第258页
# >>> 正在处理第259页
# >>> 正在处理第260页
# >>> 正在处理第261页
# >>> 正在处理第262页
# >>> 正在处理第263页
# >>> 正在处理第264页
# ********任务完成********

# %%
data_today = pd.DataFrame(all_data_json["data"], columns=['代码', '名称', '最新价', '今开', '昨收'])
data_today["获取时间"] = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')
data_today.to_csv("data/all_data_" + today + ".csv", encoding="utf-8", index=False)

# %%
data_today
# Out:
#           代码      名称     最新价      今开      昨收                 获取时间
# 0     301373     N凌玮   43.35      44   33.73  2023-02-08 23:10:50
# 1     301260    N格力博    38.3      37   30.85  2023-02-08 23:10:50
# 2     300317    珈伟新能    6.88    5.88    5.73  2023-02-08 23:10:50
# 3     688787    海天瑞声   189.6  158.92     158  2023-02-08 23:10:50
# 4     300114    中航电测   26.34   26.34   21.95  2023-02-08 23:10:50
# ...      ...     ...     ...     ...     ...                  ...
# 5275  688027    国盾量子  142.59     153  156.16  2023-02-08 23:10:50
# 5276  300071    福石控股    5.93    6.25     6.5  2023-02-08 23:10:50
# 5277  688229    博睿数据    44.9   48.52   49.26  2023-02-08 23:10:50
# 5278  002512    达华智能    4.38    4.59    4.81  2023-02-08 23:10:50
# 5279  688316  青云科技-U    47.3   51.73   51.97  2023-02-08 23:10:50
#
# [5280 rows x 6 columns]

# %% [markdown]
# # 读取昨天数据

# %%
data_yesterday = pd.read_csv("data/all_data_" + yesterday + ".csv", encoding="utf-8", dtype={'代码': object})
data_yesterday.columns = ['代码', '名称', '最新价', '昨开', '前收', '获取时间']
# data_yesterday

# %%
data_today = pd.read_csv("data/all_data_" + today + ".csv", encoding="utf-8", dtype={'代码': object})
# data_today

# %%
data_all_new = pd.merge(data_today, data_yesterday[['代码',  '昨开']], on=['代码'], how="inner")

# %%
data_today['代码'].value_counts()
# Out:
# 600001    1
# 603129    1
# 600282    1
# 300110    1
# 002371    1
#          ..
# 601326    1
# 600900    1
# 603052    1
# 002188    1
# 601568    1
# Name: 代码, Length: 5280, dtype: int64

# %%
data_all_new = data_all_new[data_all_new['最新价'] != "-"]
data_all_new = data_all_new[data_all_new['今开'] != "-"]
data_all_new = data_all_new[data_all_new['昨开'] != "-"]
data_all_new = data_all_new[data_all_new['昨收'] != "-"]
data_all_new = data_all_new[['代码', '名称', '最新价', '今开', '昨开', '昨收', '获取时间']]

for col in ['最新价', '今开', '昨开', '昨收']:
    data_all_new[col] = data_all_new[col].astype(np.float64)

# %%
data_all_new["A"] = (data_all_new["最新价"] - data_all_new["昨收"]) / (data_all_new["昨开"] - data_all_new["昨收"])
# data_all_new["A"] = data_all_new["A"].apply(lambda x: format(x, '.2%'))

# %%
data_all_new
# Out:
#           代码      名称     最新价      今开      昨开      昨收                 获取时间  \
# 2     300317    珈伟新能    6.88    5.88    5.42    5.73  2023-02-08 23:10:50
# 3     688787    海天瑞声  189.60  158.92  136.00  158.00  2023-02-08 23:10:50
# 4     300114    中航电测   26.34   26.34   21.95   21.95  2023-02-08 23:10:50
# 6     300309   *ST吉艾    1.04    0.86    0.91    0.87  2023-02-08 23:10:50
# 7     300473    德尔股份   23.96   21.00   18.56   20.06  2023-02-08 23:10:50
# ...      ...     ...     ...     ...     ...     ...                  ...
# 5271  688027    国盾量子  142.59  153.00  139.18  156.16  2023-02-08 23:10:50
# 5272  300071    福石控股    5.93    6.25    5.91    6.50  2023-02-08 23:10:50
# 5273  688229    博睿数据   44.90   48.52   49.17   49.26  2023-02-08 23:10:50
# 5274  002512    达华智能    4.38    4.59    4.46    4.81  2023-02-08 23:10:50
# 5275  688316  青云科技-U   47.30   51.73   45.99   51.97  2023-02-08 23:10:50
#
#               A
# 2     -3.709677
# 3     -1.436364
# 4           inf
# 6      4.250000
# 7     -2.600000
# ...         ...
# 5271   0.799176
# 5272   0.966102
# 5273  48.444444
# 5274   1.228571
# 5275   0.780936
#
# [5060 rows x 8 columns]

# %%
flag_ss = data_all_new['代码'].str.startswith("0") | data_all_new['代码'].str.startswith("6")
data_all_new = data_all_new[flag_ss]
data_all_new = data_all_new[data_all_new['最新价']-data_all_new['今开'] > 0]
data_all_new = data_all_new[data_all_new['A'].between(0.5, 1.5)]
data_all_new['A'] = data_all_new["A"].round(2)

# %%
# 读取股票基本信息
name_list = pd.read_csv("data/name_list_20230202.csv",
                        encoding="utf-8", dtype={'股票代码': object})
name_list.rename(columns={"股票代码": "代码"}, inplace=True)
name_list
# Out:
#           代码       名称   地区    行业   版块      上市日期
# 0     000001     平安银行   深圳    银行   主板  19910403
# 1     000002      万科A   深圳  全国地产   主板  19910129
# 2     000004     ST国华   深圳  软件服务   主板  19910114
# 3     000005     ST星源   深圳  环境保护   主板  19901210
# 4     000006     深振业A   深圳  区域地产   主板  19920427
# ...      ...      ...  ...   ...  ...       ...
# 5074  873223     荣亿精密  NaN   NaN  北交所  20220609
# 5075  873305     九菱科技  NaN   NaN  北交所  20221221
# 5076  873339     恒太照明  NaN   NaN  北交所  20221117
# 5077  873527      夜光明  NaN   NaN  北交所  20221027
# 5078  689009  九号公司-WD   北京   摩托车  CDR  20201029
#
# [5079 rows x 6 columns]

# %%
name_list['代码'].value_counts()
# Out:
# 603667    1
# 301024    1
# 002080    1
# 000416    1
# 301111    1
#          ..
# 601326    1
# 600900    1
# 600170    1
# 002153    1
# 601568    1
# Name: 代码, Length: 5079, dtype: int64

# %%
data_all_new = pd.merge(data_all_new, name_list[['代码', '地区', '行业', '版块']], on=['代码'], how="left")
data_all_new = data_all_new[['代码', '名称', '地区',
                             '行业', '版块', '最新价', '今开', '昨开', '昨收', '获取时间', 'A']]

# %%
data_all_new = data_all_new.sort_values(['代码'])
data_all_new["代码"] = "\t" + data_all_new["代码"]

# %%
data_all_new
# Out:
#            代码    名称  地区    行业   版块     最新价      今开      昨开      昨收  \
# 30   \t000007   全新好  深圳  其他商业   主板    7.71    7.63    7.69    7.62
# 94   \t000096  广聚能源  深圳  石油贸易   主板    8.52    8.50    8.53    8.51
# 92   \t000510   新金路  四川  化工原料   主板    6.46    6.44    6.47    6.45
# 65   \t000757  浩物股份  四川  汽车配件   主板    4.48    4.47    4.48    4.46
# 61   \t000786  北新建材  北京  其他建材   主板   28.01   27.88   27.97   27.86
# ..        ...   ...  ..   ...  ...     ...     ...     ...     ...
# 15   \t688625  呈和科技  广东  化工原料  科创板   54.95   54.00   55.78   54.00
# 10   \t688656   浩欧博  江苏  医疗保健  科创板   38.73   37.82   38.47   37.78
# 100  \t688670   金迪克  江苏  生物制药  科创板   47.78   47.49   47.76   47.89
# 19   \t688789  宏华数科  浙江  专用机械  科创板  186.35  184.38  186.50  183.52
# 51   \t688800   瑞可达  江苏   元器件  科创板  114.11  112.80  114.69  113.20
#
#                     获取时间     A
# 30   2023-02-08 23:10:50  1.29
# 94   2023-02-08 23:10:50  0.50
# 92   2023-02-08 23:10:50  0.50
# 65   2023-02-08 23:10:50  1.00
# 61   2023-02-08 23:10:50  1.36
# ..                   ...   ...
# 15   2023-02-08 23:10:50  0.53
# 10   2023-02-08 23:10:50  1.38
# 100  2023-02-08 23:10:50  0.85
# 19   2023-02-08 23:10:50  0.95
# 51   2023-02-08 23:10:50  0.61
#
# [112 rows x 11 columns]

# %%
data_all_new.to_excel("data/data_all_result_" + today + ".xlsx", index=False)
